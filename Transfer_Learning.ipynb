# %%
 #!pip install tensorflow_hub

# %%
import numpy as np
import pandas as pd
import cv2
import pathlib
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from sklearn.model_selection import train_test_split

# %%
classifier= keras.Sequential([hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4",input_shape=(224,224,3), trainable=False)])

# %%
img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/Gold fish.jpg", 1)

# %%
resized_img = cv2.resize(img, (224, 224))
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img_scaled=resized_img/255

# %%
img_scaled.shape
# Out:
# (224, 224, 3)

# %%
img_scaled[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
label=classifier.predict(img_scaled[np.newaxis,...])
# Out:
# 1/1 [==============================] - 1s 664ms/step

# %%
label
# Out:
# array([[ 0.2647623,  4.066013 ,  7.7166743, ..., -1.4806066,  0.3246032,
#         -0.9046265]], dtype=float32)

# %%
np.argmax(label)
# Out:
# 2

# %%
pretrained_model = hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4", input_shape = (224,224,3), trainable = False )

# %%
X=np.load("/content/drive/MyDrive/X_saved.npy")
y=np.load("/content/drive/MyDrive/y_saved.npy")

# %%
X_train,X_test , y_train ,y_test = train_test_split(X,y,test_size=0.25)

# %%
X_train = X_train/255
y_train = y_train/255

# %%
my_model.evaluate(X_test, y_test)
